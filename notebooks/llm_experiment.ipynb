# %%
pip install google-genai
# Out:
# ...
# [notice] A new release of pip is available: 26.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached google_genai-2.17.0-py3-none-any.whl.metadata (56 kB)
# ...
#   Using cached anyio-4.14.2-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached google_auth-2.56.3-py3-none-any.whl.metadata (6.0 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
# Using cached google_genai-2.17.0-py3-none-any.whl (1.0 MB)
# Using cached anyio-4.14.2-py3-none-any.whl (125 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached google_auth-2.56.3-py3-none-any.whl (259 kB)
# ...
#
#   Attempting uninstall: anyio
#
#     Found existing installation: anyio 4.6.0
#
#     Uninstalling anyio-4.6.0:
#
#    ---------- ----------------------------- 1/4 [anyio]
#       Successfully uninstalled anyio-4.6.0
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
# ...

# %%
import sys, importlib, traceback
import importlib.util
print("Python exe:", sys.executable)
print("sys.path head:", sys.path[:6])
print("find_spec google:", importlib.util.find_spec("google"))
print("find_spec google.genai:", importlib.util.find_spec("google.genai"))
try:
    import google
    print("google.__file__:", getattr(google, "__file__", None))
except Exception:
    traceback.print_exc()
# check pip installation in this interpreter
import subprocess
print(subprocess.run([sys.executable, "-m", "pip", "show", "google-genai"], capture_output=True, text=True).stdout or "not installed")
# Out:
# Python exe: c:\Users\pc\AppData\Local\Programs\Python\Python312\python.exe
# sys.path head: ['c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312', '', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']
# find_spec google: ModuleSpec(name='google', loader=<_frozen_importlib_external.NamespaceLoader object at 0x000001725383E840>, submodule_search_locations=_NamespacePath(['c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\google']))
# ...

# %%
import os, sys
from pathlib import Path
from dotenv import load_dotenv

print("cwd:", Path.cwd())
# Determine project root robustly: if running inside the repo or inside notebooks/
project_root = Path.cwd()
if not (project_root / "src").exists():
    # likely running from notebooks/ folder
    project_root = project_root.parent
print("project_root:", project_root)
print(".env exists:", (project_root / ".env").exists())

load_dotenv(project_root / ".env")
print("GEMINI_API_KEY present:", bool(os.getenv("GEMINI_API_KEY")))
print("LLM_MODEL:", os.getenv("LLM_MODEL"))

print("sys.path (head):", sys.path[:5])

try:
    import google.genai
    print("google.genai import: OK")
except Exception as e:
    print("google.genai import error:", type(e).__name__, e)
# Out:
# cwd: c:\Users\pc\Documents\ML\research-opportunity-agent\notebooks
# project_root: c:\Users\pc\Documents\ML\research-opportunity-agent
# .env exists: True
# GEMINI_API_KEY present: True
# LLM_MODEL: your_current_flash_model
# sys.path (head): ['c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\pc\\AppData\\Local\\Programs\\Python\\Python312', '']
# google.genai import error: ModuleNotFoundError No module named 'google.genai'

# %%
import sys
from pathlib import Path

# Ensure `src` package is importable from the detected project root
project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

sys.path.append(str(project_root))

# %%
from dotenv import load_dotenv
from pathlib import Path
import os
load_dotenv(Path.cwd().parent / ".env")
print("LLM_MODEL:", os.getenv("LLM_MODEL"))
# Out:
# LLM_MODEL: your_current_flash_model

# %%
from dotenv import load_dotenv

load_dotenv(project_root / ".env")

from src.llm.client import LLMClient


llm = LLMClient()

response = llm.generate(
    "Explain semantic similarity in two sentences."
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[16], line 10
#       5 from src.llm.client import LLMClient
#       8 llm = LLMClient()
# ---> 10 response = llm.generate(
#      11     "Explain semantic similarity in two sentences."
#      12 )
#      14 print(response)
#
# File c:\Users\pc\Documents\ML\research-opportunity-agent\src\llm\client.py:31, in LLMClient.generate(self, prompt)
#      30 def generate(self, prompt: str) -> str:
# ---> 31     return self.llm.generate(prompt)
#
# File c:\Users\pc\Documents\ML\research-opportunity-agent\src\llm\provider\gemini.py:22, in GeminiLLM.generate(self, prompt)
#      20 def generate(self, prompt: str) -> str:
# ---> 22     response = self.client.models.generate_content(
#      23         model=self.model_name,
#      24         contents=prompt
#      25     )
#      27     return response.text
#
# ...
